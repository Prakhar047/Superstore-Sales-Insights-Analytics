# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet

# %%
# Load the dataset
df_sales = pd.read_csv('datasets/Superstore_sales.csv')

df_sales.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812  06-09-2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
print(df_sales.isnull().sum())

# Drop rows with missing values
df_sales.dropna(inplace=True)

# Check for duplicates
print(df_sales.duplicated().sum())

# Remove duplicates if any
df_sales.drop_duplicates(inplace=True)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64
# 0

# %%
# Summary statistics of the dataset
print(df_sales.describe())
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Convert 'Order Date' to datetime format
df_sales['Order Date'] = pd.to_datetime(df_sales['Order Date'], format='mixed')
monthly_sales = df_sales.groupby(df_sales['Order Date'].dt.to_period('M'))['Sales'].sum()

# Plotting monthly sales trends
plt.figure(figsize=(12,6))
monthly_sales.plot(kind='bar')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %%
sales_by_category = df_sales.groupby('Category')['Sales'].sum()
plt.figure(figsize=(6, 6))
sns.barplot(x=sales_by_category.index, y=sales_by_category.values)
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.title('Sales by Product Category')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_products = df_sales.groupby('Product Name')['Sales'].sum().nlargest(10) # Show top 10
plt.figure(figsize=(12, 6))
sns.barplot(x=top_products.values, y=top_products.index)
plt.xlabel('Total Sales')
plt.ylabel('Product')
plt.title('Top 10 Selling Products')
plt.show()

# %%
sales_by_region = df_sales.groupby('Region')['Sales'].sum()
plt.figure(figsize=(10, 6))
sns.barplot(x=sales_by_region.index, y=sales_by_region.values)
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Sales by Region')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sales_by_state = df_sales.groupby('State')['Sales'].sum()
top_10_states = sales_by_state.nlargest(10)
plt.figure(figsize=(12, 6))
sns.barplot(y=top_10_states.values, x=top_10_states.index)
plt.xlabel('Total Sales')
plt.ylabel('State')
plt.title('Top 10 States by Sales')
plt.show()

# %%
avg_sales_region = df_sales.groupby('Region')['Sales'].mean()
print("Average Sales per Region:\n", avg_sales_region)
# Out:
# Average Sales per Region:
#  Region
# Central    215.772661
# East       238.336110
# South      241.803645
# West       226.493233
# Name: Sales, dtype: float64
